# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from skimage import io
clock = io.imread('./resources/clock.jpg')
plt.imshow(clock, cmap='gray', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
def img_convert(img,rmin,rmax):
    newImg = np.copy(img)
    for i in range(clock.shape[0]):
        for j in range(clock.shape[1]):
            a = np.array((i,j))
            b = np.array((clock.shape[0]/2, clock.shape[1]/2))
            if rmin <= np.linalg.norm(a-b) <= rmax:
                newImg[i][j] = 0
    return newImg

# %%
i = img_convert(clock,30,70)
plt.imshow(i, cmap='gray', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.savefig('converted_clock_30_70')
plt.show()

# %%
i = img_convert(clock,100,120)
plt.imshow(i, cmap='gray', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.savefig('converted_clock_100_120')
plt.show()

# %%
def img_convert_origin(img,rmin,rmax,x,y):
    newImg = np.copy(img)
    for i in range(clock.shape[0]):
        for j in range(clock.shape[1]):
            a = np.array((i,j))
            b = np.array(((clock.shape[0]/2) - y,(clock.shape[1]/2 + x)))
            if rmin <= np.linalg.norm(a-b) <= rmax:
                newImg[i][j] = 0
    return newImg

# %%
i = img_convert_origin(clock,50,70,-30,60)
plt.imshow(i, cmap='gray', interpolation='nearest')
plt.xticks([])
plt.yticks([])
plt.savefig('converted_clock_origin')
plt.show()
